# %%
import numpy as np
from numpy import matrix
import sklearn.metrics
from cvxopt import matrix, solvers
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import spearmanr 
import scanpy as sc
import seaborn as sns

# %%
#%% Kernel
def kernel(ker, X1, X2, gamma):
    K = None
    if ker == 'linear':
        if X2 is not None:
            K = sklearn.metrics.pairwise.linear_kernel(np.asarray(X1), np.asarray(X2))
        else:
            K = sklearn.metrics.pairwise.linear_kernel(np.asarray(X1))
    elif ker == 'rbf':
        if X2 is not None:
            K = sklearn.metrics.pairwise.rbf_kernel(np.asarray(X1), np.asarray(X2), gamma)
        else:
            K = sklearn.metrics.pairwise.rbf_kernel(np.asarray(X1), None, gamma)
    return K


#%% Kernel Mean Matching (KMM)
class KMM:
    def __init__(self, kernel_type='linear', gamma=1.0, B=1.0, eps=None):
        '''
        Initialization function
        :param kernel_type: 'linear' | 'rbf'
        :param gamma: kernel bandwidth for rbf kernel
        :param B: bound for beta
        :param eps: bound for sigma_beta
        '''
        self.kernel_type = kernel_type
        self.gamma = gamma
        self.B = B
        self.eps = eps

    def fit(self, Xs, Xt):
        '''
        Fit source and target using KMM (compute the coefficients)
        :param Xs: ns * dim
        :param Xt: nt * dim
        :return: Coefficients (Pt / Ps) value vector (Beta in the paper)
        '''
        ns = Xs.shape[0]
        nt = Xt.shape[0]
        if self.eps == None:
            self.eps = self.B / np.sqrt(ns)
        K = kernel(self.kernel_type, Xs, None, self.gamma)
        kappa = np.sum(kernel(self.kernel_type, Xs, Xt, self.gamma) * float(ns) / float(nt), axis=1)

        K = matrix(K)
        kappa = matrix(kappa)
        G = matrix(np.r_[np.ones((1, ns)), -np.ones((1, ns)), np.eye(ns), -np.eye(ns)])
        h = matrix(np.r_[ns * (1 + self.eps), ns * (self.eps - 1), self.B * np.ones((ns,)), np.zeros((ns,))])

        sol = solvers.qp(K, -kappa, G, h)
        beta = np.array(sol['x'])
        return beta

# %%
cell=sc.read_h5ad('cell_seurat_100.h5ad')
st=sc.read_h5ad('st_seurat_100.h5ad')

# %%
cell
# Out:
# AnnData object with n_obs × n_vars = 1691 × 132
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA'
#     var: 'features'

# %%
st
# Out:
# AnnData object with n_obs × n_vars = 10000 × 132
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA'
#     var: 'features'

# %%
cell_X=pd.DataFrame(cell.X.todense())
st_X=pd.DataFrame(st.X.todense())

# %%
kmm = KMM(kernel_type='rbf', B=1)
beta = kmm.fit(pd.DataFrame(st.X.todense()), pd.DataFrame(cell.X.todense()))
# Out:
#      pcost       dcost       gap    pres   dres
#  0:  5.5621e+06  4.8182e+06  3e+10  1e+01  1e-09
#  1:  1.4662e+07  1.7390e+07  4e+09  1e+00  3e-07
#  2:  3.4702e+07  2.7866e+07  5e+08  2e-01  2e-08
#  3:  4.2801e+07  3.0979e+07  4e+07  1e-02  2e-08
#  4:  4.3892e+07  3.9719e+07  5e+06  5e-04  8e-08
#  5:  4.3984e+07  4.3820e+07  2e+05  7e-06  1e-07
#  6:  4.3981e+07  4.3946e+07  4e+04  1e-06  9e-07
#  7:  4.3981e+07  4.3946e+07  4e+04  1e-06  2e-05
#  8:  4.3981e+07  4.3946e+07  4e+04  1e-06  2e-05
#  9:  4.3981e+07  4.3946e+07  4e+04  1e-06  3e-05
# 10:  4.3981e+07  4.3946e+07  4e+04  1e-06  4e-05
# 11:  4.3980e+07  4.3946e+07  3e+04  1e-06  4e-05
# 12:  4.3980e+07  4.3946e+07  3e+04  1e-06  5e-05
# 13:  4.3979e+07  4.3947e+07  3e+04  8e-07  4e-05
# 14:  4.3978e+07  4.3947e+07  3e+04  6e-07  3e-05
# 15:  4.3977e+07  4.3948e+07  3e+04  5e-07  4e-05
# 16:  4.3976e+07  4.3950e+07  3e+04  4e-07  2e-05
# 17:  4.3975e+07  4.3952e+07  2e+04  3e-07  3e-05
# 18:  4.3974e+07  4.3954e+07  2e+04  2e-07  9e-06
# 19:  4.3973e+07  4.3956e+07  2e+04  1e-07  1e-05
# 20:  4.3972e+07  4.3958e+07  1e+04  8e-08  8e-06
# 21:  4.3971e+07  4.3960e+07  1e+04  5e-08  2e-05
# 22:  4.3970e+07  4.3962e+07  8e+03  3e-08  3e-05
# 23:  4.3969e+07  4.3963e+07  6e+03  2e-08  3e-05
# 24:  4.3969e+07  4.3964e+07  5e+03  1e-08  5e-05
# 25:  4.3968e+07  4.3964e+07  4e+03  8e-09  3e-05
# 26:  4.3968e+07  4.3965e+07  3e+03  5e-09  8e-05
# 27:  4.3968e+07  4.3965e+07  2e+03  4e-09  5e-05
# 28:  4.3968e+07  4.3966e+07  2e+03  3e-09  6e-05
# 29:  4.3967e+07  4.3966e+07  1e+03  6e-10  2e-04
# 30:  4.3967e+07  4.3966e+07  7e+02  3e-10  1e-04
# 31:  4.3967e+07  4.3967e+07  4e+02  1e-10  1e-04
# 32:  4.3967e+07  4.3967e+07  1e+02  2e-15  1e-04
# 33:  4.3967e+07  4.3967e+07  5e+00  2e-15  3e-04
# 34:  4.3967e+07  4.3967e+07  5e-02  1e-15  2e-04
# 35:  4.3967e+07  4.3967e+07  5e-04  2e-15  2e-04
# 36:  4.3967e+07  4.3967e+07  5e-06  6e-16  4e-04
# 37:  4.3967e+07  4.3967e+07  5e-08  1e-14  5e-05
# 38:  4.3967e+07  4.3967e+07  2e-08  1e-15  7e-04
# 39:  4.3967e+07  4.3967e+07  2e-08  2e-15  1e-04
# 40:  4.3967e+07  4.3967e+07  3e-09  5e-15  5e-04
# 41:  4.3967e+07  4.3967e+07  4e-11  8e-16  8e-04
# 42:  4.3967e+07  4.3967e+07  4e-13  1e-16  1e-02
# 43:  4.3967e+07  4.3967e+07  4e-15  1e-18  2e-04
# 44:  4.3967e+07  4.3967e+07  4e-17  1e-18  1e-03
# 45:  4.3967e+07  4.3967e+07  4e-19  1e-18  3e-04
# 46:  4.3967e+07  4.3967e+07  4e-21  1e-16  3e-04
# 47:  4.3967e+07  4.3967e+07  4e-23  1e-16  5e-04
# 48:  4.3967e+07  4.3967e+07  4e-25  1e-18  6e-04
# 49:  4.3967e+07  4.3967e+07  4e-27  1e-18  2e-03
# 50:  4.3967e+07  4.3967e+07  4e-29  1e-18  6e-04
# 51:  4.3967e+07  4.3967e+07  4e-31  1e-18  7e-04
# 52:  4.3967e+07  4.3967e+07  4e-33  1e-18  7e-05
# 53:  4.3967e+07  4.3967e+07  4e-35  9e-19  1e-04
# 54:  4.3967e+07  4.3967e+07  4e-37  1e-18  6e-04
# 55:  4.3967e+07  4.3967e+07  4e-39  1e-18  5e-04
# 56:  4.3967e+07  4.3967e+07  4e-41  1e-18  7e-04
# 57:  4.3967e+07  4.3967e+07  4e-43  1e-18  1e-04
# 58:  4.3967e+07  4.3967e+07  4e-45  1e-18  8e-04
# 59:  4.3967e+07  4.3967e+07  4e-47  1e-18  7e-04
# 60:  4.3967e+07  4.3967e+07  4e-49  1e-18  1e-03
# 61:  4.3967e+07  4.3967e+07  4e-51  1e-18  1e-04
# 62:  4.3967e+07  4.3967e+07  4e-53  1e-18  7e-04
# 63:  4.3967e+07  4.3967e+07  4e-55  1e-18  9e-05
# 64:  4.3967e+07  4.3967e+07  4e-57  1e-18  4e-04
# 65:  4.3967e+07  4.3967e+07  4e-59  1e-18  4e-04
# 66:  4.3967e+07  4.3967e+07  4e-61  1e-18  2e-03
# 67:  4.3967e+07  4.3967e+07  4e-63  1e-18  4e-04
# 68:  4.3967e+07  4.3967e+07  4e-65  1e-18  7e-04
# 69:  4.3967e+07  4.3967e+07  4e-67  1e-18  7e-04
# 70:  4.3967e+07  4.3967e+07  4e-69  1e-18  8e-04
# 71:  4.3967e+07  4.3967e+07  4e-71  1e-18  8e-04
# 72:  4.3967e+07  4.3967e+07  4e-73  1e-18  7e-04
# 73:  4.3967e+07  4.3967e+07  4e-75  2e-18  1e-04
# 74:  4.3967e+07  4.3967e+07  4e-77  1e-18  1e-03
# 75:  4.3967e+07  4.3967e+07  4e-79  1e-18  1e-03
# 76:  4.3967e+07  4.3967e+07  4e-81  2e-18  5e-04
# 77:  4.3967e+07  4.3967e+07  4e-83  1e-18  1e-03
# 78:  4.3967e+07  4.3967e+07  4e-85  1e-18  1e-03
# 79:  4.3967e+07  4.3967e+07  4e-87  1e-18  3e-04
# 80:  4.3967e+07  4.3967e+07  4e-89  1e-18  5e-04
# 81:  4.3967e+07  4.3967e+07  4e-91  1e-18  9e-04
# 82:  4.3967e+07  4.3967e+07  4e-93  1e-18  5e-04
# 83:  4.3967e+07  4.3967e+07  4e-95  1e-18  1e-03
# 84:  4.3967e+07  4.3967e+07  4e-97  1e-18  9e-04
# 85:  4.3967e+07  4.3967e+07  4e-99  1e-18  1e-03
# 86:  4.3967e+07  4.3967e+07  4e-101  1e-18  6e-04
# 87:  4.3967e+07  4.3967e+07  4e-103  1e-18  4e-04
# 88:  4.3967e+07  4.3967e+07  4e-105  1e-18  1e-03
# 89:  4.3967e+07  4.3967e+07  4e-107  8e-19  5e-04
# 90:  4.3967e+07  4.3967e+07  4e-109  1e-18  1e-03
# 91:  4.3967e+07  4.3967e+07  4e-111  1e-18  7e-04
# 92:  4.3967e+07  4.3967e+07  4e-113  1e-18  2e-04
# 93:  4.3967e+07  4.3967e+07  4e-115  1e-18  4e-04
# 94:  4.3967e+07  4.3967e+07  4e-117  1e-18  1e-04
# 95:  4.3967e+07  4.3967e+07  4e-119  1e-18  8e-04
# 96:  4.3967e+07  4.3967e+07  4e-121  1e-18  1e-03
# 97:  4.3967e+07  4.3967e+07  4e-123  1e-18  1e-03
# 98:  4.3967e+07  4.3967e+07  4e-125  1e-18  2e-04
# 99:  4.3967e+07  4.3967e+07  4e-127  1e-18  2e-04
# 100:  4.3967e+07  4.3967e+07  4e-129  1e-18  1e-03
# Terminated (maximum number of iterations reached).

# %%
beta=pd.DataFrame(beta)
beta.to_csv('beta_100.csv',index= False, header=0)

# %%
beta
# Out:
#         0
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# ...   ...
# 9995  1.0
# 9996  1.0
# 9997  1.0
# 9998  1.0
# 9999  1.0
#
# [10000 rows x 1 columns]
